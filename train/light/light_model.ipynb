# %%
# !chmod +x convert_yolov5_to_cvimodel.sh && bash ./convert_yolov5_to_cvimodel.sh best "/workspace/datasets/duck1k_yolo/images/val" "/workspace/datasets/duck1k_yolo/images/train/11770_116.jpg"
# Out:
# 2024/12/03 23:59:02 - INFO : TPU-MLIR v1.12-20241105
# 2024/12/03 23:59:02 - INFO :
# 	 _____________________________________________________
# 	| preprocess:                                           |
# 	|   (x - mean) * scale                                  |
# 	'-------------------------------------------------------'
#   config Preprocess args :
# 	resize_dims           : same to net input dims
# 	keep_aspect_ratio     : True
# 	keep_ratio_mode       : letterbox
# 	pad_value             : 0
# 	pad_type              : center
# 	--------------------------
# 	mean                  : [0.0, 0.0, 0.0]
# 	scale                 : [0.003921569, 0.003921569, 0.003921569]
# 	--------------------------
# 	pixel_format          : rgb
# 	channel_format        : nchw
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tpu_mlir/python/tools/model_transform.py", line 406, in <module>
#     tool = get_model_transform(args)
#   File "/usr/local/lib/python3.10/dist-packages/tpu_mlir/python/tools/model_transform.py", line 304, in get_model_transform
#     tool = OnnxTransformer(args.model_name,
#   File "/usr/local/lib/python3.10/dist-packages/tpu_mlir/python/tools/model_transform.py", line 151, in __init__
#     self.converter = OnnxConverter(self.model_name,
#   File "/usr/local/lib/python3.10/dist-packages/tpu_mlir/python/transform/OnnxConverter.py", line 144, in __init__
#     self.load_onnx_model(onnx_file, input_shapes, output_names, static_shape, dump_final_opt)
#   File "/usr/local/lib/python3.10/dist-packages/tpu_mlir/python/transform/OnnxConverter.py", line 472, in load_onnx_model
#     self.model = onnx.load(onnx_file)
#   File "/usr/local/lib/python3.10/dist-packages/onnx/__init__.py", line 169, in load_model
#     s = _load_bytes(f)
#   File "/usr/local/lib/python3.10/dist-packages/onnx/__init__.py", line 73, in _load_bytes
#     with open(typing.cast(str, f), "rb") as readable:
# FileNotFoundError: [Errno 2] No such file or directory: '../best.onnx'

# %%
! which model_transform.py
# Out:
# /usr/local/bin/model_transform.py

# %%
! cat /usr/local/bin/model_transform.py
# Out:
# #!/usr/bin/python3
# # -*- coding: utf-8 -*-
# import re
# import sys
# from tpu_mlir.entry import model_transform
# if __name__ == '__main__':
#     sys.argv[0] = re.sub(r'(-script\.pyw|\.exe)?$', '', sys.argv[0])
#     sys.exit(model_transform())

# %%
! ls /usr/local/bin/ -asF
# Out:
# total 1095608
#      4 ./
#      4 ../
#    924 FileCheck*
#     56 UnicodeNameMappingGenerator*
#      4 __pycache__/
#      8 activate-global-python-argcomplete*
#      4 ansi2html*
#      4 assign_output*
#      4 assign_output.py*
#      4 backend-test-tools*
#      4 bmodel_checker*
#      4 bmodel_checker.py*
#      4 bmodel_combine*
#      4 bmodel_combine.py*
#      4 bmodel_dis*
#      4 bmodel_dis.py*
#      4 bmodel_dumper*
#      4 bmodel_dumper.py*
#      4 bmodel_infer*
#      4 bmodel_infer.py*
#      4 bmodel_truncater*
#      4 bmodel_truncater.py*
#      4 bmrt_test*
#      4 bmrt_test.py*
#  36796 bugpoint*
#  13680 ccmake*
#      4 chardetect*
#      4 check-model*
#      4 check-node*
#      4 classify_DenseNet*
#      4 classify_DenseNet.py*
#      4 classify_LeNet*
#      4 classify_LeNet.py*
#      4 classify_efficientnet*
#      4 classify_efficientnet.py*
#      4 classify_inception_v3*
#      4 classify_inception_v3.py*
#      4 classify_mobilenet_v2*
#      4 classify_mobilenet_v2.py*
#      4 classify_resnet18*
#      4 classify_resnet18.py*
#      4 classify_resnet50*
#      4 classify_resnet50.py*
#      4 classify_resnext50*
#      4 classify_resnext50.py*
#      4 classify_shufflenet*
#      4 classify_shufflenet.py*
#      4 classify_squeezenet*
#      4 classify_squeezenet.py*
#      4 classify_vgg16*
#      4 classify_vgg16.py*
#      4 classify_xception*
#      4 classify_xception.py*
#  13728 cmake*
#  28776 cmake-gui*
#      4 code_stripper*
#      4 code_stripper.py*
#      4 coloredlogs*
#      4 compare_visualizer*
#      4 compare_visualizer.py*
#      4 convert-caffe2-to-onnx*
#      4 convert-onnx-to-caffe2*
#      8 count*
#  14148 cpack*
#      4 cpuinfo*
#  15112 ctest*
#      4 cvimodel_debug*
#      4 cvimodel_debug.py*
#      4 cygdb*
#      4 cython*
#      4 cythonize*
#      4 dash-generate-components*
#      4 dash-update-components*
#      4 detect_pp_picodet*
#      4 detect_pp_picodet.py*
#      4 detect_pp_yoloe*
#      4 detect_pp_yoloe.py*
#      4 detect_pp_yolox*
#      4 detect_pp_yolox.py*
#      4 detect_retinaface*
#      4 detect_retinaface.py*
#      4 detect_ssd-12*
#      4 detect_ssd-12.py*
#      4 detect_ultraface*
#      4 detect_ultraface.py*
#      4 detect_yolov3*
#      4 detect_yolov3.py*
#      4 detect_yolov5*
#      4 detect_yolov5.py*
#  11380 dsymutil*
#      4 duration_BW_usage_statistics*
#      4 duration_BW_usage_statistics.py*
#      4 envsetup.sh*
#      4 estimator_ckpt_converter*
#      4 f2py*
#      4 f2py3*
#      4 f2py3.10*
#      4 flask*
#   5344 flatc*
#      4 fleetrun*
#      4 fonttools*
#      4 fp_forward*
#      4 fp_forward.py*
#      4 gen_rand_input*
#      4 gen_rand_input.py*
#      4 gen_shell*
#      4 gen_shell.py*
#     20 gflags2man.py
#      4 google-oauthlib-tool*
#      4 httpx*
#      4 huggingface-cli*
#      4 humanfriendly*
#      4 imageio_download_bin*
#      4 imageio_remove_bin*
#      4 import_pb_to_tensorboard*
#      4 ipython*
#      4 ipython3*
#      4 isympy*
#      4 jlpm*
#      4 jsonpointer*
#      4 jsonschema*
#      4 jupyter*
#      4 jupyter-bundlerextension*
#      4 jupyter-console*
#      4 jupyter-contrib*
#      4 jupyter-contrib-nbextension*
#      4 jupyter-dejavu*
#      4 jupyter-events*
#      4 jupyter-execute*
#      4 jupyter-kernel*
#      4 jupyter-kernelspec*
#      4 jupyter-lab*
#      4 jupyter-labextension*
#      4 jupyter-labhub*
#      4 jupyter-migrate*
#      4 jupyter-nbconvert*
#      4 jupyter-nbextension*
#      4 jupyter-nbextensions_configurator*
#      4 jupyter-notebook*
#      4 jupyter-run*
#      4 jupyter-server*
#      4 jupyter-serverextension*
#      4 jupyter-troubleshoot*
#      4 jupyter-trust*
#      4 keyring*
#      4 lit*
#      4 livereload*
#  39708 llc*
#  38996 lli*
#   1832 lli-child-target*
#     20 llvm-PerfectShuffle*
#      0 llvm-addr2line@
#   6464 llvm-ar*
#   5804 llvm-as*
#    680 llvm-bcanalyzer*
#      0 llvm-bitcode-strip@
#   6240 llvm-c-test*
#   5304 llvm-cat*
#   8240 llvm-cfi-verify*
#    268 llvm-config*
#   7276 llvm-cov*
#    688 llvm-cvtres*
#   6236 llvm-cxxdump*
#    608 llvm-cxxfilt*
#    796 llvm-cxxmap*
#   9456 llvm-debuginfo-analyzer*
#   6264 llvm-debuginfod*
#    768 llvm-debuginfod-find*
#   4860 llvm-diff*
#   4656 llvm-dis*
#      0 llvm-dlltool@
#   7216 llvm-dwarfdump*
#  11528 llvm-dwarfutil*
#   3476 llvm-dwp*
#  10692 llvm-exegesis*
#  13708 llvm-extract*
#   7264 llvm-gsymutil*
#   6296 llvm-ifs*
#      0 llvm-install-name-tool@
#  23312 llvm-jitlink*
#   1876 llvm-jitlink-executor*
#      0 llvm-lib@
#   6416 llvm-libtool-darwin*
#   6752 llvm-link*
#   6324 llvm-lipo*
#  36364 llvm-lto*
#  50628 llvm-lto2*
#   2228 llvm-mc*
#   1848 llvm-mca*
#   2020 llvm-ml*
#   5448 llvm-modextract*
#    476 llvm-mt*
#   6632 llvm-nm*
#   7208 llvm-objcopy*
#   9256 llvm-objdump*
#    808 llvm-opt-report*
#      0 llvm-otool@
#   9256 llvm-pdbutil*
#   8448 llvm-profdata*
#   9388 llvm-profgen*
#      0 llvm-ranlib@
#    960 llvm-rc*
#      0 llvm-readelf@
#  10456 llvm-readobj*
#  35484 llvm-reduce*
#    864 llvm-remark-size-diff*
#    896 llvm-remarkutil*
#   2900 llvm-rtdyld*
#   5200 llvm-sim*
#   6224 llvm-size*
#   6136 llvm-split*
#   3632 llvm-stress*
#    552 llvm-strings*
#      0 llvm-strip@
#   8364 llvm-symbolizer*
#   6292 llvm-tapi-diff*
#   5180 llvm-tblgen*
#   6392 llvm-tli-checker*
#    680 llvm-undname*
#      0 llvm-windres@
#   8792 llvm-xray*
#      4 logdebug_tool*
#      4 logdebug_tool.py*
#      4 lsm2bin*
#      4 markdown-it*
#      4 markdown_py*
#   2620 mlir-cat*
#   2660 mlir-linalg-ods-yaml-gen*
#  60096 mlir-lsp-server*
#   4084 mlir-minimal-opt*
#   6408 mlir-minimal-opt-canonicalize*
# 142272 mlir-opt*
#   3768 mlir-pdll*
#   4236 mlir-pdll-lsp-server*
#  77604 mlir-reduce*
#   2864 mlir-tblgen*
#  40612 mlir-translate*
#      4 mlir2graph*
#      4 mlir2graph.py*
#      4 mlir2onnx*
#      4 mlir2onnx.py*
#      4 mlir_cut*
#      4 mlir_cut.py*
#      4 model_deploy*
#      4 model_deploy.py*
#      4 model_eval*
#      4 model_eval.py*
#      4 model_eval_imagenet*
#      4 model_eval_imagenet.py*
#      4 model_inference_cpu*
#      4 model_inference_cpu.py*
#      4 model_runner*
#      4 model_runner.py*
#      4 model_tool*
#      4 model_tool.py*
#      4 model_transform*
#      4 model_transform.py*
#      4 normalizer*
#      4 nosetests*
#      4 nosetests-3.4*
#    132 not*
#      4 npz_tool*
#      4 npz_tool.py*
#   9596 obj2yaml*
#      4 onnxruntime_test*
#      4 onnxsim*
#      4 op_locator*
#      4 op_locator.py*
#  50876 opt*
#      8 paddle*
#      4 paddle2onnx*
#      4 pkginfo*
#      4 pmu_dump*
#      4 pmu_dump.py*
#      4 py.test*
#      4 pybabel*
#      4 pyftmerge*
#      4 pyftsubset*
#      4 pygmentize*
#      4 pyjson5*
#      4 pyproject-build*
#      4 pyrsa-decrypt*
#      4 pyrsa-encrypt*
#      4 pyrsa-keygen*
#      4 pyrsa-priv2pub*
#      4 pyrsa-sign*
#      4 pyrsa-verify*
#      4 pytest*
#      4 python-argcomplete-check-easy-install-script*
#      4 register-python-argcomplete*
#      4 remote_test*
#      4 remote_test.py*
#      4 renderer*
#      4 riscv_code_opt*
#      4 riscv_code_opt.py*
#      4 rst2html.py*
#      4 rst2html4.py*
#      4 rst2html5.py*
#      4 rst2latex.py*
#      4 rst2man.py*
#      4 rst2odt.py*
#      4 rst2odt_prepstyles.py*
#      4 rst2pdf*
#      4 rst2pseudoxml.py*
#      4 rst2s5.py*
#      4 rst2xetex.py*
#      4 rst2xml.py*
#      4 rstpep2html.py*
#      4 run_calibration*
#      4 run_calibration.py*
#      4 run_qtable*
#      4 run_qtable.py*
#      4 run_sensitive_layer*
#      4 run_sensitive_layer.py*
#   8304 sancov*
#   8128 sanstats*
#      4 saved_model_cli*
#      4 seg_humanseg*
#      4 seg_humanseg.py*
#      4 send2trash*
#      4 smartypants*
#      4 sphinx-apidoc*
#      4 sphinx-autobuild*
#      4 sphinx-autogen*
#      4 sphinx-build*
#      4 sphinx-quickstart*
#    360 split-file*
#   1172 tblgen-lsp-server*
#      4 tdb*
#      4 tdb.py*
#      4 tensorboard*
#      4 test_custom_tpulang*
#      4 test_custom_tpulang.py*
#      4 test_onnx*
#      4 test_onnx.py*
#      4 test_tpulang*
#      4 test_tpulang.py*
#      4 tf_upgrade_v2*
#      4 tflite_convert*
#      4 tiff2fsspec*
#      4 tiffcomment*
#      4 tifffile*
#      4 toco*
#      4 toco_from_protos*
#      4 tool_maskrcnn*
#      4 tool_maskrcnn.py*
#      4 torchrun*
#      4 tpu_profile*
#      4 tpu_profile.py*
#      4 tpuc-opt*
#      4 tpuc-opt.py*
#      4 tpuc-tool*
#      4 tpuc-tool.py*
#      4 tqdm*
#      4 transformers-cli*
#      4 ttx*
#      4 twine*
#      4 ultralytics*
#   6240 verify-uselistorder*
#      4 visual*
#      4 visual.py*
#      4 wsdump*
#    476 yaml-bench*
#   3052 yaml2obj*
#      4 yolo*

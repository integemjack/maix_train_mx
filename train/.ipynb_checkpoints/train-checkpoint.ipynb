# %% [markdown]
# # Train

# %%
! python yolov5/train.py --img 224 --epoch 30 --data duck1k_dataset.yaml --weights yolov5s.pt --workers 0
# Out:
# 2024-11-28 14:07:02.912464: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=duck1k_dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=224, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=0, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.8.10 torch-2.4.1+cu121 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|█████████████████████████████████████████| 755k/755k [00:00<00:00, 100MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /app/datasets/duck1k_yolo/labels/train... 654 images, 112 backgr
# train: New cache created: /app/datasets/duck1k_yolo/labels/train.cache
# val: Scanning /app/datasets/duck1k_yolo/labels/val... 654 images, 0 backgrounds,
# val: New cache created: /app/datasets/duck1k_yolo/labels/val.cache
#
# AutoAnchor: 6.23 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp4/labels.jpg...
# yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to yolov5/runs/train/exp4
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/48 [00:00<?, ?it/s]yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1203   0.009953          0         27        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1219   0.009472          0         28        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1228    0.00967          0         32        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1225   0.009841          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1221    0.01008          0         31        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1218     0.0102          0         30        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1216    0.01029          0         29        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1215    0.01058          0         38        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1212    0.01077          0         36        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1208    0.01069          0         25        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1204    0.01051          0         19        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1201    0.01079          0         38        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1198     0.0108          0         28        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1194    0.01087          0         31        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1188    0.01103          0         30        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1183    0.01097          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1178    0.01117          0         33        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1173    0.01139          0         35        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G      0.117    0.01131          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1162    0.01139          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1157    0.01137          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1153    0.01152          0         31        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1147    0.01152          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1143    0.01155          0         25        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1137     0.0115          0         20        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1132    0.01151          0         23        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1127    0.01159          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1123     0.0117          0         31        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1119    0.01178          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1114     0.0118          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G      0.111    0.01201          0         38        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1106    0.01201          0         23        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1102    0.01208          0         25        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1097     0.0123          0         37        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1092    0.01236          0         24        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1088    0.01243          0         29        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1084    0.01255          0         33        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1079    0.01263          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1075    0.01273          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G      0.107    0.01272          0         20        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1066    0.01282          0         29        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G      0.106    0.01288          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1056    0.01293          0         25        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G      0.105      0.013          0         24        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1047    0.01313          0         37        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1044    0.01328          0         38        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1041    0.01333          0         29        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1037    0.01338          0         25        224: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        654        654      0.307      0.277      0.201     0.0558
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/48 [00:00<?, ?it/s]Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08436    0.01248          0         21        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08488    0.01329          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08445    0.01291          0         20        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08471    0.01454          0         34        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08438    0.01486          0         27        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08476    0.01536          0         33        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08421    0.01555          0         28        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08362     0.0156          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08298     0.0157          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08244    0.01588          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08238    0.01565          0         25        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08205    0.01568          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08202    0.01604          0         35        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.0812     0.0161          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08085    0.01596          0         25        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08053    0.01565          0         17        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.08023    0.01581          0         32        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07975    0.01593          0         31        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07971    0.01597          0         34        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.0792    0.01602          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07925    0.01597          0         31        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07891     0.0159          0         23        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07845    0.01586          0         25        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07821    0.01593          0         31        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07779    0.01591          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07732    0.01591          0         26        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07707    0.01589          0         28        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07667     0.0159          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07637    0.01604          0         35        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07606    0.01602          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07591    0.01595          0         24        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07569    0.01592          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07555    0.01594          0         32        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07541    0.01595          0         32        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07512    0.01593          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07487     0.0158          0         19        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07473    0.01576          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07468    0.01574          0         29        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07458    0.01568          0         24        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.0744    0.01561          0         23        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07442    0.01549          0         20        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07427    0.01544          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07401    0.01539          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07384     0.0154          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07375     0.0154          0         28        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07366    0.01534          0         25        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.0735     0.0153          0         22        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G    0.07342     0.0153          0         25        224: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        654        654      0.292      0.602      0.278     0.0697
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/48 [00:00<?, ?it/s]Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06204    0.01506          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06372    0.01456          0         25        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06576    0.01475          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06584    0.01503          0         31        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06578    0.01571          0         35        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06527    0.01512          0         21        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06552    0.01483          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06644    0.01472          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06668    0.01485          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G     0.0665    0.01474          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06614    0.01463          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06567    0.01475          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06591    0.01458          0         22        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06602    0.01454          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06608    0.01467          0         33        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06598    0.01479          0         34        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06593    0.01476          0         25        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G      0.066    0.01476          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06573    0.01484          0         30        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06571    0.01482          0         27        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06561    0.01475          0         24        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06551     0.0147          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06551    0.01466          0         28        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06559    0.01463          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06542    0.01453          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06524     0.0146          0         31        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G    0.06537     0.0146          0         29        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03695   0.009646          0         23        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03698   0.009662          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03703   0.009655          0         26        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03706   0.009641          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03704    0.00971          0         37        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03697   0.009724          0         29        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G      0.037   0.009679          0         24        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03701   0.009741          0         32        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03705   0.009787          0         35        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03716   0.009767          0         24        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03707   0.009787          0         36        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03717    0.00976          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03715   0.009748          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03714   0.009722          0         24        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03714   0.009679          0         24        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03713   0.009626          0         24        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03702   0.009604          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03703   0.009651          0         32        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03696   0.009607          0         20        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03694    0.00957          0         23        224: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        654        654      0.985      0.985      0.986      0.504
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/48 [00:00<?, ?it/s]Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03692    0.01083          0         32        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03581     0.0103          0         26        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03558   0.009646          0         24        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03518   0.009431          0         28        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03605   0.009361          0         23        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03574   0.009859          0         35        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G     0.0353   0.009539          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G     0.0356   0.009281          0         22        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03567    0.00907          0         22        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03545   0.009046          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G     0.0364   0.009243          0         28        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03622   0.009316          0         28        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03624   0.009251          0         25        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03617   0.009335          0         31        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03623   0.009307          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03586   0.009286          0         25        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G     0.0359   0.009295          0         26        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03561   0.009291          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03574   0.009428          0         30        224:  Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03596   0.009575          0         37        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G      0.036   0.009547          0         26        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03594   0.009525          0         27        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03587    0.00945          0         21        224:  yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03588   0.009545          0         38        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G     0.0358   0.009513          0         22        224:  Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.03569   0.009619          0         37        224:

# %% [markdown]
# # Convert to ONNX

# %%
! python yolov5/export.py --weight yolov5/runs/train/exp/weights/best.pt --include onnx --img 224 320

# %% [markdown]
# # Generate .mud file

# %%
model_name = "best_int8.cvimodel"
label = ["duck"]
save_path = "best_int8.mud"

# write to file
with open(save_path, 'w') as f:
    f.write("[basic]\n")
    f.write("type = cvimodel\n")
    f.write("model = %s\n" % model_name)
    f.write("\n")
    f.write("[extra]\n")
    f.write("model_type = yolov5\n")
    f.write("input_type = rgb\n")
    f.write("mean = 0, 0, 0\n")
    f.write("scale = 0.00392156862745098, 0.00392156862745098, 0.00392156862745098\n")
    f.write("anchors = 10,13, 16,30, 33,23, 30,61, 62,45, 59,119, 116,90, 156,198, 373,326\n")
    f.write("labels = %s\n" % ",".join(label))

print("done")
